# %% [markdown]
# <a href="https://colab.research.google.com/github/sofgqv/UTEC_202101_ICC_104_Grupo02/blob/main/Visualizaci%C3%B3nDatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Visualización de Datos

# %%
# !pip install graphviz

# %%
from graphviz import Digraph

# %% [markdown]
# Digraph: Grafo Dirigido

# %%
grafo = Digraph()
#agregar vértices
grafo.node('A')
grafo.node('B')
grafo.node('C')

#agregar aristas
grafo.edges(['AB', 'BC'])
#mostrar grafo
grafo

# %% [markdown]
# ## Grafo no dirgido

# %%
from graphviz import Graph
g = Graph()
g.edge('Colombia', 'Perú')
g.edge('Perú', 'Chile')
g.edge('Chile', 'Argentina')
g.edge('Argentina', 'Brasil')
g

# %%
from graphviz import Graph
g = Graph()
g.edge('Colombia', 'Perú')
g.edge('Perú', 'Chile')
g.edge('Chile', 'Argentina')
g.edge('Argentina', 'Brasil')
g.edge('Perú', 'Brasil')
g

# %%
from graphviz import Graph
g = Graph()
g.edge('Colombia', 'Perú')
g.edge('Perú', 'Chile')
g.edge('Chile', 'Argentina')
g.edge('Argentina', 'Brasil')
g.edge('Perú', 'Brasil',color='red')
g

# %%
from graphviz import Graph
g = Graph()
g.edge('Colombia', 'Perú', color='red')
g.edge('Perú', 'Chile', color='red')
g.edge('Chile', 'Argentina')
g.edge('Argentina', 'Brasil')
g.edge('Perú', 'Brasil')
g

# %%
paises = ['Colombia', 'Perú', 'Chile', 'Argentina', 'Brasil']
vecinos = {'Colombia':["Perú"], 'Perú':["Colombia","Chile","Brasil"], "Chile":["Argentina", "Perú"], "Argentina":["Chile",'Brasil'], "Brasil":['Argentina', 'Perú']}

# %%
vecinos
# Out:
# {'Argentina': ['Chile', 'Brasil'],
#  'Brasil': ['Argentina', 'Perú'],
#  'Chile': ['Argentina', 'Perú'],
#  'Colombia': ['Perú'],
#  'Perú': ['Colombia', 'Chile', 'Brasil']}

# %%
pais = input("De qué país quieres saber su vecino: ")
#Reportamos la lista de vecinos
print(vecinos[pais])
# Out:
# De qué país quieres saber su vecino: Perú
# ['Colombia', 'Chile', 'Brasil']

# %% [markdown]
# # Actividad Grupal

# %%
N = int(input("Ingrese cuántos países forman la red de courier:"))
# Out:
# Ingrese cuántos países forman la red de courier:6

# %% [markdown]
# "Ingrese el nombre del país [1]:"

# %%
# Ejemplo de un país y sus vecinos
pais = "Perú"
lista = vecinos[pais]
print(lista)
# Out:
# ['Colombia', 'Chile', 'Brasil']

# %%
# Ejemplo graficando un solo país y sus vecinos
from graphviz import Graph
g = Graph()
for v in lista: 
  g.edge(pais, v, color='black')
g
